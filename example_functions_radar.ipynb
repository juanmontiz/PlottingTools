# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
#
from functions_radar_v0 import *

np.random.seed(0)

# Example RSNs
rsn_labels = ["DMN", "Visual", "Auditory", "Motor", "Attention", "Salience"]

# Synthetic data for 5 groups
groups = [
    {"label": "Wakefulness", "values": np.random.rand(len(rsn_labels)) + 5},
    {"label": "Deep Sleep", "values": np.random.rand(len(rsn_labels)) + 4},
    {"label": "Control", "values": np.random.rand(len(rsn_labels)) + 3},
    {"label": "MCS", "values": np.random.rand(len(rsn_labels)) + 2},
    {"label": "UWS", "values": np.random.rand(len(rsn_labels)) + 1},
]

plot_radar(groups, rsn_labels, title="Non-Equilibrium per RSN (Synthetic Data)")
